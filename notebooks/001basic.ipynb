// %%
import { ChatDeepSeek } from "@langchain/deepseek";
import { HumanMessage } from "@langchain/core/messages";
const model = new ChatDeepSeek(
    {
        model:'deepseek-chat'
    }
)

await model.invoke([
    new HumanMessage("讲一个笑话")
])
// Out:
// AIMessage {
//   "id": "29c9e6ab-1194-46fa-b67d-6b9d4d302b5d",
//   "content": "当然可以！这是一个经典的笑话：\n\n有一天，小明去参加考试，老师发下试卷后，小明看了看题目，突然举手问：“老师，这道题我不会做，能不能给点提示？”\n\n老师看了看题目，笑着说：“这道题是选择题，选项是A、B、C、D，你随便选一个吧。”\n\n小明想了想，说：“那我选E。”\n\n老师愣了一下，说：“没有E选项啊！”\n\n小明淡定地回答：“那这道题我肯定做对了，因为E选项不存在。”\n\n老师：……😅\n\n希望这个笑话能让你笑一笑！",
//   "additional_kwargs": {},
//   "response_metadata": {
//     "tokenUsage": {
//       "promptTokens": 6,
//       "completionTokens": 118,
//       "totalTokens": 124
//     },
//     "finish_reason": "stop",
//     "model_name": "deepseek-chat",
//     "usage": {
//       "prompt_tokens": 6,
//       "completion_tokens": 118,
//       "total_tokens": 124,
//       "prompt_tokens_details": {
//         "cached_tokens": 0
//       },
//       "prompt_cache_hit_tokens": 0,
//       "prompt_cache_miss_tokens": 6
//     },
//     "system_fingerprint": "fp_3a5770e1b4_prod0225"
//   },
//   "tool_calls": [],
//   "invalid_tool_calls": [],
//   "usage_metadata": {
//     "output_tokens": 118,
//     "input_tokens": 6,
//     "total_tokens": 124,
//     "input_token_details": {
//       "cache_read": 0
//     },
//     "output_token_details": {}
//   }
// }

// %%
// outputparse可以处理输出
// pipe组装多个 Runnable 对象形成完整的 Chain
import {StringOutputParser} from '@langchain/core/output_parsers'
const outputPrase = new StringOutputParser();
const simpleChain = model.pipe(outputPrase)
await simpleChain.invoke([
    new HumanMessage("讲一个笑话")
])
// Out:
// "当然！这是一个经典的笑话：\n" +
//   "\n" +
//   "有一天，小明去面试。面试官问他：“你有什么特长吗？”\n" +
//   "\n" +
//   "小明想了想，说：“我会预测未来。”\n" +
//   "\n" +
//   "面试官很好奇，问：“那你预测一下，你什么时候能被录用？”\n" +
//   "\n" +
//   "小明淡定地回答：“这个嘛……我预测我不会被录用。”\n" +
//   "\n" +
//   "面试官笑了：“你预测错了，你被录用了！”\n" +
//   "\n" +
//   "小明摇摇头：“不，我预测对了，因为我不打算来上班。”\n" +
//   "\n" +
//   "😂"

// %%
// 批量调用
await simpleChain.batch([
    [ new HumanMessage("讲一个笑话") ],
    [ new HumanMessage("讲一个冷笑话") ],
])
// Out:
// [
//   "当然可以！这是一个经典的笑话：\n" +
//     "\n" +
//     "有一天，小明去参加面试。面试官问他：“你有什么特长吗？”\n" +
//     "\n" +
//     "小明想了想，认真地说：“我会预测未来。”\n" +
//     "\n" +
//     "面试官笑了笑，说：“那你预测一下，你什么时候能拿到这份工作？”\n" +
//     "\n" +
//     "小明淡定地回答：“这个嘛……我预测我不会拿到这份工作。”\n" +
//     "\n" +
//     "面试官愣了一下，笑着说：“你被录用了！我们需要你这样诚实的人！”\n" +
//     "\n" +
//     "希望这个笑话能让你笑一笑！😄",
//   "有一天，一只鸭子走进一家药店，问店员：“你们有葡萄吗？”  \n" +
//     "店员回答：“这里是药店，我们不卖葡萄。”  \n" +
//     "第二天，鸭子又来了，问：“你们有葡萄吗？”  \n" +
//     "店员有点无奈，还是回答：“这里是药店，我们不卖葡萄。”  \n" +
//     "第三天，鸭子又来了，问：“你们有葡萄吗？”  \n" +
//     "店员终于忍不住了，说：“你要是再问有没有葡萄，我就把你的嘴粘上！”  \n" +
//     "第四天，鸭子来了，问：“你们有胶水吗？”  \n" +
//     "店员说：“没有。”  \n" +
//     "鸭子点点头：“那你们有葡萄吗？”  \n" +
//     "\n" +
//     "😅"
// ]

// %%
// 流式调用
const stream = await simpleChain.stream([
     new HumanMessage("讲一个笑话")
])

for await (const chunk of stream){
    console.log(chunk)
}
// Out:
// 当然
// 可以
// ！
// 这是一个
// 简单的
// 笑话
// ：
//
//
// 有一天
// ，
// 小明
// 去
// 参加
// 面试
// 。
// 面试
// 官
// 问他
// ：“
// 你有什么
// 特长
// 吗
// ？”
//
//
// 小明
// 想了想
// ，
// 认真
// 地说
// ：“
// 我会
// 预测
// 未来
// 。”
//
//
// 面试
// 官
// 很
// 感兴趣
// ，
// 问
// ：“
// 那你
// 预测
// 一下
// ，
// 你
// 什么时候
// 能被
// 录用
// ？”
//
//
// 小明
// 微微一笑
// ，
// 说
// ：“
// 这个
// 嘛
// ……
// 我
// 预测
// 我不会
// 被
// 录用
// 。”
//
//
//
// 面试
// 官
// 愣了一下
// ，
// 笑着说
// ：“
// 你
// 预测
// 错了
// ，
// 你
// 被
// 录
// 用了
// ！”
//
//
// 小明
// 耸
// 耸肩
// ：“
// 你看
// ，
// 我的
// 预测
// 果然
// 不准
// 。”
//
//
// 希望
// 这个
// 笑话
// 能
// 让你
// 笑
// 一笑
// ！
//  😄
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

// %%
// 流式调用,每次返回对象
const stream = await simpleChain.streamLog([
     new HumanMessage("讲一个笑话")
])

for await (const chunk of stream){
    console.log(chunk)
}
// Out:
// RunLogPatch {
//   ops: [
//     {
//       op: "replace",
//       path: "",
//       value: {
//         id: "226522a3-6605-4d87-8830-f7d76e9bf9a1",
//         name: "RunnableSequence",
//         type: "chain",
//         streamed_output: [],
//         final_output: undefined,
//         logs: {}
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek",
//       value: {
//         id: "f40f53e2-f6e8-43b3-8652-598a5cfb0800",
//         name: "ChatDeepSeek",
//         type: "llm",
//         tags: [ "seq:step:1" ],
//         metadata: {
//           ls_provider: "openai",
//           ls_model_name: "deepseek-chat",
//           ls_model_type: "chat",
//           ls_temperature: undefined,
//           ls_max_tokens: undefined,
//           ls_stop: undefined
//         },
//         start_time: "2025-03-06T09:31:46.256Z",
//         streamed_output: [],
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser",
//       value: {
//         id: "4d18fe0c-0d3a-422d-af90-49c38d698b60",
//         name: "StrOutputParser",
//         type: "parser",
//         tags: [ "seq:step:2" ],
//         metadata: {},
//         start_time: "2025-03-06T09:31:53.606Z",
//         streamed_output: [],
//         streamed_output_str: [],
//         final_output: undefined,
//         end_time: undefined
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: ""
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: ""
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "##"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "##" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "##"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "##",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "##",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: " 《"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: " 《" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: " 《"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: " 《",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": " 《",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "相亲"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "相亲" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "相亲"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "相亲",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "相亲",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "记"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "记" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "记"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "记",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "记",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "》\n\n"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "》\n\n" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "》\n\n"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "》\n\n",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "》\n\n",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '"'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '"' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '"'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '"',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "\"",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "叮"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "叮" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "叮"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "叮",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "叮",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "咚"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "咚" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "咚"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "咚",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "咚",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "——"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "——" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "——"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "——",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "——",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '"\n\n'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '"\n\n' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '"\n\n'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '"\n\n',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "\"\n\n",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "门"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "门" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "门"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "门",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "门",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "铃声"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "铃声" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "铃声"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "铃声",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "铃声",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "响起"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "响起" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "响起"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "响起",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "响起",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "的时候"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "的时候" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "的时候"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "的时候",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "的时候",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "，"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "，" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "，"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "，",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "，",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "我"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "我" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "我"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "我",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "我",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "正"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "正" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "正"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "正",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "正",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "对着"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "对着" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "对着"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "对着",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "对着",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "镜子"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "镜子" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "镜子"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "镜子",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "镜子",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "整理"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "整理" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "整理"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "整理",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "整理",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "领"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "领" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "领"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "领",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "领",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "带"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "带" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "带"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "带",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "带",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "。"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "。" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "。"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "。",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "。",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "镜"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "镜" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "镜"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "镜",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "镜",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "中的"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "中的" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "中的"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "中的",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "中的",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "男人"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "男人" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "男人"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "男人",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "男人",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "西装"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "西装" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "西装"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "西装",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "西装",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "笔"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "笔" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "笔"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "笔",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "笔",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "挺"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "挺" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "挺"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "挺",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "挺",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "，"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "，" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "，"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "，",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "，",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "头发"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "头发" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "头发"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "头发",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "头发",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "梳"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "梳" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "梳"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "梳",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "梳",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "得"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "得" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "得"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "得",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "得",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "一丝"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "一丝" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "一丝"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "一丝",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "一丝",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "不苟"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "不苟" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "不苟"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "不苟",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "不苟",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "，"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "，" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "，"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "，",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "，",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "连"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "连" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "连"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "连",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "连",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "皮鞋"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "皮鞋" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "皮鞋"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "皮鞋",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "皮鞋",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "都"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "都" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "都"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "都",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "都",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "擦"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "擦" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "擦"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "擦",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "擦",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "得"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "得" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "得"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "得",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "得",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "锃"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "锃" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "锃"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "锃",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "锃",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "亮"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "亮" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "亮"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "亮",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "亮",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "。"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "。" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "。"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "。",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "。",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "这是我"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "这是我" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "这是我"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "这是我",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "这是我",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "第一次"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "第一次" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "第一次"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "第一次",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "第一次",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "相亲"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "相亲" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "相亲"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "相亲",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "相亲",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "，"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "，" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "，"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "，",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "，",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "必须"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "必须" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "必须"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "必须",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "必须",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "给"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "给" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "给"
//     },
// ...
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "！"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "！" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "！"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "！",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "！",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '"\n\n'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '"\n\n' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '"\n\n'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '"\n\n',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "\"\n\n",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '"'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '"' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '"'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '"',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "\"",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "小"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "小" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "小"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "小",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "小",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "美"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "美" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "美"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "美",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "美",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '"'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '"' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '"'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '"',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "\"",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "听到"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "听到" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "听到"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "听到",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "听到",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "声音"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "声音" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "声音"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "声音",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "声音",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "，"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "，" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "，"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "，",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "，",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "立刻"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "立刻" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "立刻"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "立刻",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "立刻",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "缩"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "缩" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "缩"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "缩",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "缩",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "成一"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "成一" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "成一"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "成一",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "成一",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "团"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "团" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "团"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "团",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "团",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: '："'
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: '："' } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: '："'
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: '："',
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "：\"",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "姐姐"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "姐姐" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "姐姐"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "姐姐",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "姐姐",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "..."
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "..." } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "..."
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "...",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "...",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/StrOutputParser/streamed_output/-",
//       value: "我"
//     }
//   ]
// }
// RunLogPatch {
//   ops: [ { op: "add", path: "/streamed_output/-", value: "我" } ]
// }
// RunLogPatch {
//   ops: [
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output_str/-",
//       value: "我"
//     },
//     {
//       op: "add",
//       path: "/logs/ChatDeepSeek/streamed_output/-",
//       value: ChatGenerationChunk {
//         text: "我",
//         generationInfo: { prompt: 0, completion: 0 },
//         message: AIMessageChunk {
//           "id": "a2fd2292-2458-4616-ab5f-b0ec6820407f",
//           "content": "我",
//           "additional_kwargs": {},
//           "response_metadata": {
//             "prompt": 0,
//             "completion": 0,
//             "usage": {}
//           },
//           "tool_calls": [],
//           "tool_call_chunks": [],
//           "invalid_tool_calls": []
//         }
//       }
//     }
//   ]
// }

// %%
// fallback
const fakeLLM = new ChatDeepSeek({
    azureOpenAIApiKey: "123",
    maxRetries: 0,
});

await fakeLLM.invoke("你好")
// Out:
// Stack trace:
// Error: 400 Model Not Exist
//     at APIError.generate (file:///C:/Users/mudssky/AppData/Local/deno/npm/4873/openai/4.86.2/error.mjs:41:20)
//     at OpenAI.makeStatusError (file:///C:/Users/mudssky/AppData/Local/deno/npm/4873/openai/4.86.2/core.mjs:292:25)
//     at OpenAI.makeRequest (file:///C:/Users/mudssky/AppData/Local/deno/npm/4873/openai/4.86.2/core.mjs:336:30)
//     at eventLoopTick (ext:core/01_core.js:177:7)
//     at async file:///C:/Users/mudssky/AppData/Local/deno/npm/4873/@langchain/openai/0.4.4_1/dist/chat_models.js:1523:29
//     at async RetryOperation._fn (file:///C:/Users/mudssky/AppData/Local/deno/npm/4873/p-retry/4.6.2/index.js:50:12)

// %%
// 使用withFallbacks在模型不可用时添加替代品，可以在极端环境下保证至少有输出
const llmWithFallback = fakeLLM.withFallbacks({
    fallbacks: [model]
})
await fakeLLM.invoke("你好")
// Out:
// Stack trace:
// ReferenceError: fakeLLM is not defined
//     at <anonymous>:2:25
